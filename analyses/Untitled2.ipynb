# %%
import numpy as np
import netCDF4 as nc

# %%
fname_1="/vortexfs1/share/jilab/zahner-ssf2020/larval-dispersal-modeling/data/model_sims/baseline/yellowtail-flounder/1984/04/fiscm_group_001.nc"
fname_2="/vortexfs1/share/jilab/zahner-ssf2020/larval-dispersal-modeling/data/model_sims/baseline/yellowtail-flounder/1985/04/fiscm_group_001.nc-002"

# %%
dset_1 = nc.Dataset(fname_1)
dset_2 = nc.Dataset(fname_2)

# %%
xs1, ys1 = dset_1['x'][:].data, dset_1['y'][:].data

# %%
xs1=xs1[-1, :]
ys1=ys1[-1, :]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
s = ax.scatter(xs1, ys1, s=0.01)

# %%
xs2, ys2 = dset_2['x'][:].data, dset_2['y'][:].data

# %%
xs2=xs2[-1, :]
ys2=ys2[-1, :]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
s = ax.scatter(xs2, ys2, s=0.01)
